# %% [markdown]
# <a href="https://colab.research.google.com/github/SHANTANUBOKEY011/Capstone-project1-EDA-Airbnb/blob/main/Airbnb_EDA_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Airbnb booking analysis**    :

# %% [markdown]
# # What is Airbnb?
#
# ## Airbnb, Inc. is an American company that operates an online marketplace for lodging, primarily homestays for vacation rentals, and tourism activities. Based in San Francisco, California, the platform is accessible via website and mobile app.

# %% [markdown]
# ## **Project Type**    - EDA(Exploratory data analysis)
# #### **Contribution**    - Individual
# #### **Team member 1**            - Shantanu bokey

# %% [markdown]
# ##**GITHUB LINK**.

# %% [markdown]
# https://github.com/SHANTANUBOKEY011

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# ##Since 2008, guests and hosts have used Airbnb to expand on travelling possibilities and present a more unique, personalised way of experiencing the world. Today Airbnb became one of a kind service that is used and recognised by the whole world. Data analysis on millions of listings provided through Airbnb is a crucial factor for the company. these millions of listings generate a lot of data - data that can be analysed and used for security, business decisions, understanding of customer's and provider's (hosts) behaviour and performance on the platform, guiding marketing initiatives, implementation of innovative additional services and much more. This dataset has around 49,000 observations in it with 16 columns and it is a mix of categorical and numeric values. Explore and analyse the data to discover key understandings##
#
# ***What can we learn about different hosts and areas?***
#
# ***What can we learn from predictions? (ex: locations, prices, reviews, etc)***
#
# ***Which hosts are the busiest and why?***
#
# ***Is there any noticeable difference of traffic among different areas and what could be the reason for it?.***

# %% [markdown]
# #*Airbnb business objective*
#
# ***Airbnb (ABNB) is an online marketplace that connects people who want to rent out their homes with people who are looking for accommodations in specific locales.***
#
# ***Airbnb (ABNB) helps provider(host) and customer to sell and find good rooms/appartments/homes thus reducing their effort and time consumption.***
#
# ***Provide accomodation at affordable range according to their need.***
#
# ***What can we learn about different hosts and areas?***
#
# ***What can we learn from predictions? (ex: locations, prices, reviews, etc)***
#
# ***Which hosts are the busiest and why?***
#
# ***Is there any noticeable difference of traffic among different areas and what could be the reason for it?***

# %% [markdown]
# # ***Knowing the Data***

# %% [markdown]
# *id = unique id of listing*
#
# *name = name of listing*
#
# *host id = unique host id*
#
# *host name = name of the host*
#
# *neighbourhood group = location*
#
# *neighbourhood = area*
#
# *lattitude = listing lattitude*
#
# *longitude = listing longitude*
#
# *room type = type of listing (entire room, private room, shared room)*
#
# *room type = type of listing (entire room, private room, shared room)*
#
# *price = price of listing*
#
# *minimum nights =  the minimum number stay of nights that a guest must require to stay*
#
# *number_of_reviews = number of reviews, it will not be reliable for an individual listing (especially as reviews occasionally vanish from the site), but over a city as a whole it should be a useful metric of traffic.*
#
# *last_review = date of the last review*
#
# *reviews_per_month = insights into frequency of visits of the listing*
#
# *calculated_host_listings_count = total count of listing on airbnb*
#
# *availability_365 = an indicator of the total number of days the listing is available for during the year (i.e. if all the available days are rented out, then the listing's occupancy rate is 100%)*

# %% [markdown]
# ### Import Libraries and mount drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
# mount the drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# upload the data using pandas module
df = pd.read_csv("/content/Airbnb NYC 2019.csv")

# %%
#first view of data
df.head(3)
# Out:
#      id                                 name  host_id  host_name  \
# 0  2539   Clean & quiet apt home by the park     2787       John
# 1  2595                Skylit Midtown Castle     2845   Jennifer
# 2  3647  THE VILLAGE OF HARLEM....NEW YORK !     4632  Elisabeth
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
# 2           Manhattan        Harlem  40.80902  -73.94190     Private room
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0    149               1                  9  2018-10-19               0.21
# 1    225               1                 45  2019-05-21               0.38
# 2    150               3                  0         NaN                NaN
#
#    calculated_host_listings_count  availability_365
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
df.shape
# Out:
# (48895, 16)

# %% [markdown]
# ### Dataset Information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
#removing duplicated values.
df.drop_duplicates(inplace = True)

# %% [markdown]
# #### Missing Values/Null Values

# %%
df.isnull()
# Out:
#           id   name  host_id  host_name  neighbourhood_group  neighbourhood  \
# 0      False  False    False      False                False          False
# 1      False  False    False      False                False          False
# 2      False  False    False      False                False          False
# 3      False  False    False      False                False          False
# 4      False  False    False      False                False          False
# ...      ...    ...      ...        ...                  ...            ...
# 48890  False  False    False      False                False          False
# 48891  False  False    False      False                False          False
# 48892  False  False    False      False                False          False
# 48893  False  False    False      False                False          False
# 48894  False  False    False      False                False          False
#
# ...

# %%
# number of null values in column.
df.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
#visualising missing values.

import seaborn as sns
sns.heatmap(df.isnull(), cbar=False)
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# 1) The dataset contains total of 48895 rows and 16 columns.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df.tail()
# Out:
#              id                                               name   host_id  \
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
#            host_name neighbourhood_group       neighbourhood  latitude  \
# 48890        Sabrina            Brooklyn  Bedford-Stuyvesant  40.67853
# 48891        Marisol            Brooklyn            Bushwick  40.70184
# 48892  Ilgar & Aysel           Manhattan              Harlem  40.81475
# 48893            Taz           Manhattan      Hell's Kitchen  40.75751
# 48894     Christophe           Manhattan      Hell's Kitchen  40.76404
#
# ...

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# *id = unique id of listing*
#
# *name = name of listing*
#
# *host id = unique host id*
#
# *host name = name of the host*
#
# *neighbourhood group = location*
#
# *neighbourhood = area*
#
# *lattitude = listing lattitude*
#
# *longitude = listing longitude*
#
# *room type = type of listing (entire room, private room, shared room)*
#
# *room type = type of listing (entire room, private room, shared room)*
#
# *price = price of listing*
#
# *minimum nights =  the minimum number stay of nights that a guest must require to stay*
#
# *number_of_reviews = number of reviews, it will not be reliable for an individual listing (especially as reviews occasionally vanish from the site), but over a city as a whole it should be a useful metric of traffic.*
#
# *last_review = date of the last review*
#
# *reviews_per_month = insights into frequency of visits of the listing*
#
# *calculated_host_listings_count = total count of listing on airbnb*
#
# *availability_365 = an indicator of the total number of days the listing is available for during the year (i.e. if all the available days are rented out, then the listing's occupancy rate is 100%)*

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
df.nunique()
# Out:
# id                                48895
# name                              47905
# host_id                           37457
# host_name                         11452
# neighbourhood_group                   5
# neighbourhood                       221
# latitude                          19048
# longitude                         14718
# room_type                             3
# price                               674
# minimum_nights                      109
# number_of_reviews                   394
# last_review                        1764
# reviews_per_month                   937
# calculated_host_listings_count       47
# availability_365                    366
# dtype: int64

# %% [markdown]
# ***there are unique id for every listing. there are 37457 host id. each host id is different as per the room type, location.***

# %%
df.neighbourhood_group.unique()
# Out:
# array(['Brooklyn', 'Manhattan', 'Queens', 'Staten Island', 'Bronx'],
#       dtype=object)

# %%
df.room_type.unique()
# Out:
# array(['Private room', 'Entire home/apt', 'Shared room'], dtype=object)

# %%
# estimated revenues
df['revenues'] = df['price']*df['minimum_nights']
df.T.head(5)
# Out:
#                                                   0      \
# id                                                 2539
# name                 Clean & quiet apt home by the park
# host_id                                            2787
# host_name                                          John
# neighbourhood_group                            Brooklyn
#
#                                      1      \
# id                                    2595
# name                 Skylit Midtown Castle
# host_id                               2845
# host_name                         Jennifer
# neighbourhood_group              Manhattan
#
#                                                    2      \
# id                                                  3647
# name                 THE VILLAGE OF HARLEM....NEW YORK !
# host_id                                             4632
# host_name                                      Elisabeth
# neighbourhood_group                            Manhattan
#
# ...

# %% [markdown]
# ##3. ***Data Wrangling /cleaning***

# %%
# dropping unimportant columns like "last_review".

df.drop(["last_review"],axis = 1 ,inplace = True)

# %%
# Removing duplicate values
df.drop_duplicates(inplace = True)

# %%
# describe numerical data
df.describe().astype(int).T
# Out:
#                                 count      mean       std   min      25%  \
# id                              48895  19017143  10983108  2539  9471945
# host_id                         48895  67620010  78610967  2438  7822033
# latitude                        48895        40         0    40       40
# longitude                       48895       -73         0   -74      -73
# price                           48895       152       240     0       69
# minimum_nights                  48895         7        20     1        1
# number_of_reviews               48895        23        44     0        1
# reviews_per_month               38843         1         1     0        0
# calculated_host_listings_count  48895         7        32     1        1
# availability_365                48895       112       131     0        0
# revenues                        48895      1284     11804     0      135
#
#                                      50%        75%        max
# ...

# %%
# describe categorical data
df.describe(include='O').T
# Out:
#                      count unique              top   freq
# name                 48879  47905   Hillside Hotel     18
# host_name            48874  11452          Michael    417
# neighbourhood_group  48895      5        Manhattan  21661
# neighbourhood        48895    221     Williamsburg   3920
# room_type            48895      3  Entire home/apt  25409

# %% [markdown]
# **price, minimum nights, number of reviews, reviews per month, calculated host listing count, availability of room during 365 are the numerical data**.
#
# minimum price is 0 and maximum is 10,000.
#
# **average price** per listing is 152.
#
# on an **average people has to stay for 7 days** in a room.
#
# maximum minimum nights is 1250 days.
#
#  **average number of reviews** is 23 and highest is 629.
#
#  **average availability of rooms** over the year is 112.
#
#   **average host listing count is 7** and highest is 327.

# %%
df.fillna({"host_name": "No_name"},inplace = True)

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# 1)dropping unimportant columns like "last_review"".
#
# 2)removing duplicates rows and columns if any .
#
# 3)removing empty values in rows and columns .
#
# 4)filling the required null values.(" host_name" with "No_name")

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# ##a)
# ##Exploring Neighbourhood-Groups and Room-types

# %%
df.neighbourhood_group.unique()
# Out:
# array(['Brooklyn', 'Manhattan', 'Queens', 'Staten Island', 'Bronx'],
#       dtype=object)

# %% [markdown]
# **There are 5 Neighbourhood-Groups called**
#
# * Manhattan
# * Brooklyn
# * Queens
# * Bronx
# * Staten Island

# %%
hosts_areas = df.groupby(['host_name','neighbourhood_group'])['calculated_host_listings_count'].max().reset_index()
hosts_areas.sort_values(by='calculated_host_listings_count', ascending=False).head(5)
# Out:
#           host_name neighbourhood_group  calculated_host_listings_count
# 13221  Sonder (NYC)           Manhattan                             327
# 1833     Blueground            Brooklyn                             232
# 1834     Blueground           Manhattan                             232
# 7275           Kara           Manhattan                             121
# 7478         Kazuya            Brooklyn                             103

# %%
sns.barplot(x = 'neighbourhood_group',y= 'calculated_host_listings_count' ,data = hosts_areas )
# Out:
# <Axes: xlabel='neighbourhood_group', ylabel='calculated_host_listings_count'>

# %% [markdown]
# ####As we can see most number of listings are from **Manhattan** created Sonder (NYC), Blueground, Michael, David

# %% [markdown]
# ##b).
# ##What can we learn from predictions? (ex: locations, prices, reviews, etc)

# %%
areas_reviews = df.groupby(['neighbourhood_group'])['number_of_reviews'].max().reset_index()
areas_reviews
# Out:
#   neighbourhood_group  number_of_reviews
# 0               Bronx                321
# 1            Brooklyn                488
# 2           Manhattan                607
# 3              Queens                629
# 4       Staten Island                333

# %%
sns.barplot(x = 'neighbourhood_group',y= 'number_of_reviews' ,data =areas_reviews  )
# Out:
# <Axes: xlabel='neighbourhood_group', ylabel='number_of_reviews'>

# %% [markdown]
# ####Here we can say that "Queens" get maximum number of reviews and "Bronx" has minimum number of reviews.

# %% [markdown]
# ##c)#
# ##Highest revenue Earning host .

# %%
manhattan_airbnb = df[(df['neighbourhood_group']=='Manhattan') & (df['revenues']>=10000)].sort_values(by='revenues',ascending=False).head(10)
brooklyn_airbnb = df[(df['neighbourhood_group']=='Brooklyn') & (df['revenues']>=10000)].sort_values(by='revenues',ascending=False).head(10)
queens_airbnb = df[(df['neighbourhood_group']=='Queens') & (df['revenues']>=10000)].sort_values(by='revenues',ascending=False).head(10)
bronx_airbnb = df[(df['neighbourhood_group']=='Bronx') & (df['revenues']>=5000)].sort_values(by='revenues',ascending=False).head(10)
staten_island_airbnb = df[(df['neighbourhood_group']=='Staten Island') & (df['revenues']>=5000)].sort_values(by='revenues',ascending=False).head(10)

# %%
fig,axes =plt.subplots(3,2,figsize=(20,12))

axes[0,0].set_title('highest revenue earning host in manhattan group')
sns.barplot(x=manhattan_airbnb.host_name,y=manhattan_airbnb.revenues,hue=manhattan_airbnb.room_type,ax=axes[0,0])

axes[0,1].set_title('highest revenue earning host in brooklyn group')
sns.barplot(x=brooklyn_airbnb.host_name,y=brooklyn_airbnb.revenues,hue=brooklyn_airbnb.room_type,ax=axes[0,1])

axes[1,0].set_title('highest revenue earning host in queens group')
sns.barplot(x=queens_airbnb.host_name,y=queens_airbnb.revenues,hue=queens_airbnb.room_type,ax=axes[1,0])

axes[1,1].set_title('highest revenue earning host in bronx group')
sns.barplot(x=bronx_airbnb.host_name,y=bronx_airbnb.revenues,hue=bronx_airbnb.room_type,ax=axes[1,1])

axes[2,0].set_title('highest revenue earning host in staten island group')
sns.barplot(x=staten_island_airbnb.host_name,y=staten_island_airbnb.revenues,hue=staten_island_airbnb.room_type,ax=axes[2,0])

axes[2,1].set_title('revenues earning distribution by neighbourhood group')  #highest revenue earning neighbourhood group
sns.barplot(x=df['neighbourhood_group'],y=df['revenues'],ax=axes[2,1])

plt.tight_layout(pad=1)

# %% [markdown]
# * highest revenue earned **by one visit and by one listing is of Jenny, Amy, Peter, Adam, Jelena, etc in Manhattan NG**.
# * highest revenue earned **by one visit and by one listing is of Jeffrey, Mark, Adela etc in Brooklyn NG**
# * highest revenue earned **by one visit and by one listing is of Kathrine,Iveta,Noelle etc in Queens NG**.
# * highest revenue earned **by one visit and by one listing is of Vicdania, John, Sasha etc in Bronx NG**.
# * highest revenue earned **by one visit and by one listing is of Janine, Anastasios,Mary,Mark etc in Staten Island NG**.
# * highest revenue is earned by the neighbourhood group Manhatten.we can conclude that **Manhattan** area is much **crowdy** or **most demanded location**. and least by Bronx neighbourhood group.

# %% [markdown]
# ##d)
# ##Availibility of room per year

# %%
#lets count the availability of room over the year
entire_room = df[df['room_type']=='Entire home/apt']
private_room = df[df['room_type']=='Private room']
share_room = df[df['room_type']=='Shared room']

plt.figure(figsize=(13,7))
plt.title("count of availability of rooms over the year")
plt.hist(entire_room.availability_365,bins=20,alpha=0.5)
plt.hist(private_room.availability_365,bins=20,alpha=0.5)
plt.hist(share_room.availability_365,bins=20,alpha=0.5)
plt.legend(['entire room','private room','share room'])


plt.show();

# %% [markdown]
# ###here we can see that there is much less availability of room. **most of the listings are available only for 0-20 days** by host for booking.

# %% [markdown]
# ##e)
# ##distribution and frequency of prices in different region

# %%
# distribution of neighbourhood group and neighbourhood along lattitude and longitude
plt.figure(figsize=(16,8))
plt.subplot(1,2,1)
sns.scatterplot(data=df['neighbourhood_group'],x=df['longitude'],y=df['latitude'],hue=df['neighbourhood_group']);

plt.subplot(1,2,2)
x = sns.scatterplot(data=df['neighbourhood'],x=df['longitude'],y=df['latitude'],hue=df['neighbourhood']);
x.legend_ = None

plt.show()

# %%
#distribution and frequency of prices in different region
plt.figure(figsize=(16,8))
plt.subplot(1,2,1)
plt.title('distribution of price between the range of 0 to 1000')
sns.scatterplot(x=df.longitude,y=df.latitude,hue=df[df['price']<=1000].price,s=20)
plt.subplot(1,2,2)
plt.title('distribution of price between the range of 1000 to 10000')
sns.scatterplot(x=df.longitude,y=df.latitude,hue=df[df['price']>=1000].price,s=20)

plt.show()

# %% [markdown]
# ##here we can see that **highest frequency of listing is in price range of 0 to 1000**. **least frequency** is in the **price range of 1000 to 10000**.

# %% [markdown]
# ##f)
# ##correlation between different attributes

# %%
#correlation between different attributes
corr = df.corr(method='kendall')
plt.figure(figsize=(10,6))
plt.title("Correlation Between Different Variables")
sns.heatmap(corr, annot=True)
plt.show()
# Out:
# <ipython-input-39-c1c83037df72>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.corr(method='kendall')

# %% [markdown]
# ##here the **highest correlation is between the number of reviews and reviews per month**. followed by revenues and minimum nights. and revenues and price.

# %% [markdown]
# ##g)
# ##Neighbourhood_group and price relation.

# %%
price_above_100 = df[(df['price']>=100)&(df['price']<=2000)]
plt.figure (figsize= (7,7))
ax= sns.boxplot(data=price_above_100,x='neighbourhood_group',y='price',palette='plasma')

# %% [markdown]
# ##**in prices range** there is **no limit of fixation of the prices by airbnb**. hence **there are so many outliers occured in the prices**.

# %% [markdown]
# ##h)
# ##Bivariate Analysis or Relationship of Numerical Features

# %%
plt.figure(figsize=(12,12))
categorical_data = df[['number_of_reviews','neighbourhood_group','price','room_type','minimum_nights','availability_365','reviews_per_month']]
sns.pairplot(categorical_data,hue='room_type');

# %% [markdown]
# ##From above plot
# * **no_of_reviews vs price :** we can see from above pairplot that as the price increases number of reviews decreases. and the **lower price = higher number of reviews**. **highest number of reviews** are getting by the listing whose **price range is between 0-1000$**. also **highest number of reviews is getting by the listing of private room type**.
#  * **minimum_nights vs availability_365 :** most of host set minimum nights stay for 2-200 days in the particular year.
#  * **no_of_reviews vs minimum_nights :** **most of the number of reviews** are from those whose **minimum night stay is for 0-100 nights**. we can see as we go upper along the minimum night axis it is begining to diminished. also we can say that most host prefer to **rent out their property for long term**.
#  * **minimum_nights vs price:** most host whose requirement of minimum night is high they prefer to put less price range.
#  * **reviews per month vs price:** we can see that, highest frequency of visit i.e. high reviews per month = where there is less price
#  * **reviews per month vs minimum nights:** from above scatter plot, we can see, highest frequency of visits i.e. high reviews per month = where there is less minimum nights stay requirement.

# %% [markdown]
# ##i)
# ##Relationship of Categorical Features

# %%
#setting the figure size size and fontsize
plt.figure(figsize=(14,8))
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
ax = plt.axes()
ax.set_facecolor("black")
#Plotting violin graph to show the relationship between catgorical feature vs price numeric column
sns.violinplot(x=df['neighbourhood_group'],y=df['price'],hue=df['room_type'])
# Out:
# <Axes: xlabel='neighbourhood_group', ylabel='price'>

# %% [markdown]
# #From above plot
#
# ####In Manhattan Shared room and Entire home/apt type contributes same amount of price.
#
# ####Most of the rooms are in price below 2000 in all neighborhoods group.
#
# ####Shared room type in Each Neighborhood contributes low price. In Queens and Manhattan state private room price contributes equal amount.
#
# ####Manhattan, Brooklyn,Queens has highest price of rooms per night.It may be also a extreme data points.

# %% [markdown]
# ##j)
# ##Which 'neighbourhood_group' has the highest number of AirBnb's ?

# %%
plt.figure(figsize=(10,6))
plt.title("Neighbourhood Group",fontsize = 16)
plt.pie(df.neighbourhood_group.value_counts(), labels=df.neighbourhood_group.value_counts().index,autopct='%1.1f%%')
plt.show()

# %% [markdown]
# ##As we can see from the bar chart above Manhattan neighbourhood has the highest number of AirBnb's
#
# ###Manhattan
# ###Brooklyn
# ###Queens
# ###Bronx
# ###Staten Island
# ##And Manhattan and Brooklyn has more than 75% of the AirBnb's.

# %% [markdown]
# #5)Solution to business objective.
#
# #### whose requirement of minimum night is high they should be to allowed put less price range.
#
# ####As the price increases number of reviews decreases,so maintain a affordable price for the customers.
#
# ####Manhattan and Brooklyn has more than 75% of the AirBnb's. So other areas also need to be focused upon.

# %% [markdown]
# #Conclusion.

# %% [markdown]
# 1. As we can see most number of listings are from **Manhattan** created Sonder (NYC), Blueground, Michael, David.
#
# 2. Here we can say that "Queens" get maximum number of reviews and "Bronx" has minimum number of reviews.
#
# 3. highest revenue earned by one visit and by one listing is of Jenny, Amy, Peter, Adam, Jelena, etc in Manhattan NG.
#
# 4.highest revenue earned by one visit and by one listing is of Jeffrey, Mark, Adela etc in Brooklyn NG.
#
# 5.highest revenue earned by one visit and by one listing is of Kathrine,Iveta,Noelle etc in Queens NG.
#
# 6.highest revenue earned by one visit and by one listing is of Vicdania, John, Sasha etc in Bronx NG.
#
# 7.highest revenue earned by one visit and by one listing is of Janine, Anastasios,Mary,Mark etc in Staten Island NG.
#
# 8.highest revenue is earned by the neighbourhood group Manhatten.we can conclude that Manhattan area is much crowdy or most demanded location. and least by Bronx neighbourhood group.
#
# 9.here we can see that highest frequency of listing is in price range of 0 to 1000. least frequency is in the price range of 1000 to 10000.
#
# 10.here the highest correlation is between the number of reviews and reviews per month. followed by revenues and minimum nights. and revenues and price.
#
# 11.in prices range there is no limit of fixation of the prices by airbnb. hence there are so many outliers occured in the prices.
#
# 12.no_of_reviews vs price : we can see from above pairplot that as the price increases number of reviews decreases. and the lower price = higher number of reviews. highest number of reviews are getting by the listing whose price range is between 0-1000$. also highest number of reviews is getting by the listing of private room type.
#
#
# 13.minimum_nights vs availability_365 : most of host set minimum nights stay for 2-200 days in the particular year.
#
#
# 14.no_of_reviews vs minimum_nights : most of the number of reviews are from those whose minimum night stay is for 0-100 nights. we can see as we go upper along the minimum night axis it is begining to diminished. also we can say that most host prefer to rent out their property for long term.
#
#
# 15.minimum_nights vs price: most host whose requirement of minimum night is high they prefer to put less price range.
#
# 16.reviews per month vs price: we can see that, highest frequency of visit i.e. high reviews per month = where there is less price
#
# 17.reviews per month vs minimum nights: from above scatter plot, we can see, highest frequency of visits i.e. high reviews per month = where there is less minimum nights stay requirement.
#
# 18.As we can see from the bar chart above Manhattan neighbourhood has the highest number of AirBnb's
# Manhattan
# Brooklyn
# Queens
# Bronx
# Staten Island
# And Manhattan and Brooklyn has more than 75% of the AirBnb's.
